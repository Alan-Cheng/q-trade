# %%
import backtrader as bt
import setup_path
import pandas as pd
from datetime import datetime, timedelta
from alanq.data import StockDataManager
from alanq.backtest import StockPickerWorker
from alanq.factors import RegressAnglePicker
import math

class TurtleLongWithSelection(bt.Strategy):
    """
    海龜交易法 - 只做多版本 (Backtrader)
    
    規則摘要：
    - 入場：
        系統1：收盤價突破過去 20 日最高價 → 建多單
        系統2：收盤價突破過去 55 日最高價 → 建多單
        (任一系統給出多頭訊號即可，只要目前沒有持倉)
    - 出場：
        系統1：跌破過去 10 日最低價 → 全部出場
        系統2：跌破過去 20 日最低價 → 全部出場
        以及：跌破「入場價 - 2N」的停損價 → 全部出場
    - N 值：ATR(20)
    - 部位大小：單筆風險 = 帳戶淨值 * risk_per_trade
                  停損距離 = 2N
    - 加碼：每漲 0.5N 加碼 1 單位，最多 max_units 單位
    - 僅做多，不做空
    """

    params = dict(
        # 趨勢參數
        sys1_entry=20,   # 系統1突破 (高點)
        sys1_exit=10,    # 系統1出場 (低點)
        sys2_entry=55,   # 系統2突破 (高點)
        sys2_exit=20,    # 系統2出場 (低點)

        # 波動與風險控管
        atr_period=20,
        risk_per_trade=0.01,   # 單筆風險佔帳戶淨值比例 (1%)
        atr_mult_stop=2.0,     # 停損距離 = 2N
        atr_step_pyramid=0.5,  # 每 0.5N 加碼一次
        max_units=4,           # 單一商品最多單位

        point_value=1.0,       # 每一價格單位的價值 (股票通常 = 1；期貨要自己設)
        
        # 選股相關參數
        selection_data_manager=None,  # 用於選股的資料管理器（包含一個月前的資料）
        selection_lookback_days=30,    # 選股回測時間（天數）
        rebalance_frequency=1,        # 重新選股的頻率（每 N 個交易日）
    )

    def __init__(self):
        # 為每個資料源初始化技術指標
        self.indicators = {}
        self.orders = {}
        self.units = {}
        self.entry_prices = {}
        self.stop_prices = {}
        self.next_add_prices = {}
        
        # 為每個資料源創建指標
        for i, data in enumerate(self.datas):
            symbol = data._name if hasattr(data, '_name') else f'data{i}'
            self.indicators[symbol] = {
                'atr': bt.ind.ATR(data, period=self.p.atr_period),
                's1_high': bt.ind.Highest(data.high(-1), period=self.p.sys1_entry),
                's1_low_exit': bt.ind.Lowest(data.low(-1), period=self.p.sys1_exit),
                's2_high': bt.ind.Highest(data.high(-1), period=self.p.sys2_entry),
                's2_low_exit': bt.ind.Lowest(data.low(-1), period=self.p.sys2_exit),
            }
            self.orders[symbol] = None
            self.units[symbol] = 0
            self.entry_prices[symbol] = None
            self.stop_prices[symbol] = None
            self.next_add_prices[symbol] = None
        
        # 選股相關
        self.selected_symbols = set()  # 當前選中的股票
        self.last_selection_date = None
        self.trading_day_count = 0
        
        # 選股配置：角度大於5度小於20度
        self.stock_picker_config = [{
            'class': RegressAnglePicker,
            'threshold_ang_min': 5.0,
            'threshold_ang_max': 20.0,
            'reversed': False
        }]

    # 計算每個 unit 的張數/股數
    def _calc_unit_size(self, symbol):
        """計算部位大小，嚴格防止 NaN 擴散"""
        
        # 1. 取得帳戶價值
        value = self.broker.getvalue()
        # 防呆：如果帳戶已經壞掉了，就回傳 0
        if value is None or math.isnan(value) or value <= 0:
            return 0
        
        risk_amount = value * self.p.risk_per_trade

        # 2. 取得 ATR (N值)
        N = self.indicators[symbol]['atr'][0]
        
        # 防呆：ATR 必須是有效的正數
        # math.isnan(N) 是最關鍵的檢查
        if N is None or math.isnan(N) or N <= 0:
            return 0

        # 3. 計算單位風險
        unit_risk = self.p.atr_mult_stop * N * self.p.point_value
        
        # 防呆：除數不能為 0 或 NaN
        if math.isnan(unit_risk) or unit_risk <= 0:
            return 0

        # 4. 計算數量
        size_float = risk_amount / unit_risk
        
        # 最後防呆：確保算出來的 size 是有效數字
        if math.isnan(size_float) or math.isinf(size_float) or size_float <= 0:
            return 0
        
        try:
            size = int(size_float)
            return max(size, 0)
        except:
            return 0
    
    def _perform_stock_selection(self, current_date):
        """
        執行選股掃描 (改良版：包含代碼對齊與除錯資訊)
        """
        if self.p.selection_data_manager is None:
            self.log("警告: 未設定 selection_data_manager，無法執行選股")
            return
        
        # 1. 計算日期範圍
        try:
            # 結束日：昨天的日期 (避免用到當日未來資料)
            selection_end_date = (current_date - timedelta(days=1)).strftime('%Y-%m-%d')
            # 開始日：回推 N 天
            selection_start_date = (current_date - timedelta(days=self.p.selection_lookback_days)).strftime('%Y-%m-%d')
        except Exception as e:
            self.log(f"日期計算錯誤: {e}")
            return

        try:
            # 2. 取得資料子集 (Subset)
            # 注意：若資料量極大，這一步會較慢
            selection_data = self.p.selection_data_manager.subset(selection_start_date, selection_end_date)
            
            # 3. 執行選股 Worker
            picker_worker = StockPickerWorker(selection_data, self.stock_picker_config)
            picker_worker.fit()
            
            # 取得原始選股結果 (可能是 int, 或含 .TW 的字串)
            raw_picker_symbols = picker_worker.choice_symbols
            
            # =========================================================
            # 4. 關鍵改良：代碼對齊 (Symbol Alignment)
            # =========================================================
            
            # 取得 Backtrader 中目前所有已載入的 Data Feed 名稱
            # 建立一個 mapping 以便快速查找: {'2330': '2330', '2330.TW': '2330.TW'}
            bt_data_names = {d._name: d._name for d in self.datas}
            
            final_matched_symbols = set()
            
            for raw_s in raw_picker_symbols:
                s_str = str(raw_s).strip() # 強制轉字串並去空白
                
                # 情況 A: 完全匹配 (例如 Picker="2330", BT="2330")
                if s_str in bt_data_names:
                    final_matched_symbols.add(bt_data_names[s_str])
                    
                # 情況 B: Picker 有 .TW，但 BT 沒有 (例如 Picker="2330.TW", BT="2330")
                elif s_str.replace('.TW', '') in bt_data_names:
                    final_matched_symbols.add(bt_data_names[s_str.replace('.TW', '')])
                
                # 情況 C: Picker 沒有 .TW，但 BT 有 (例如 Picker="2330", BT="2330.TW")
                elif f"{s_str}.TW" in bt_data_names:
                    final_matched_symbols.add(bt_data_names[f"{s_str}.TW"])

            # 更新策略的選股清單
            self.selected_symbols = final_matched_symbols
            self.last_selection_date = current_date
            
            # =========================================================
            # 5. 詳細日誌 (讓你確認是否對齊成功)
            # =========================================================
            if len(self.selected_symbols) > 0:
                # 為了避免 Log 太長，只印前 5 檔
                example_stocks = list(self.selected_symbols)[:5]
                self.log(
                    f'選股結果: Picker選出 {len(raw_picker_symbols)} 檔 -> '
                    f'與BT匹配成功 {len(self.selected_symbols)} 檔 '
                    f'(範例: {example_stocks} ...)'
                )
            else:
                # 如果 Picker 有選出東西，但匹配後是 0，代表代碼格式有問題
                if len(raw_picker_symbols) > 0:
                    self.log(
                        f'警告: 選股匹配失敗！Picker 選出 {len(raw_picker_symbols)} 檔 (如 {list(raw_picker_symbols)[0]}), '
                        f'但無法對應到 Backtrader 的資料名稱 (如 {self.datas[0]._name})'
                    )
                else:
                    self.log('選股完成: 無符合條件股票')

        except Exception as e:
            self.log(f'選股過程發生例外錯誤: {e}')
            import traceback
            traceback.print_exc() # 印出詳細錯誤以便除錯
            
            # 如果出錯，為了安全起見，可以選擇清空或保持原狀
            # self.selected_symbols = set()

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print(f'{dt.isoformat()} - {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # 仍在撮合中
            return

        # 找出該訂單對應的股票
        symbol = None
        for s, o in self.orders.items():
            if o == order:
                symbol = s
                break
        
        symbol_str = f'[{symbol}] ' if symbol else ''

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    f'{symbol_str}BUY EXECUTED, Price: {order.executed.price:.2f}, '
                    f'Size: {order.executed.size}, Cost: {order.executed.value:.2f}'
                )
            elif order.issell():
                self.log(
                    f'{symbol_str}SELL EXECUTED, Price: {order.executed.price:.2f}, '
                    f'Size: {order.executed.size}, Cost: {order.executed.value:.2f}'
                )

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log(f'{symbol_str}Order Canceled/Margin/Rejected')

        # 無論如何，清掉掛單狀態
        if symbol:
            self.orders[symbol] = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        # 找出該交易對應的股票
        symbol = None
        for s in self.indicators.keys():
            if hasattr(trade.data, '_name') and trade.data._name == s:
                symbol = s
                break
        
        symbol_str = f'[{symbol}] ' if symbol else ''
        self.log(
            f'{symbol_str}TRADE PROFIT, Gross: {trade.pnl:.2f}, Net: {trade.pnlcomm:.2f}'
        )

    def next(self):
        # 獲取當前日期
        current_date = self.datas[0].datetime.date(0)
        self.trading_day_count += 1
        
        # 檢查是否需要執行選股（每個交易日或根據頻率）
        if (self.last_selection_date is None or 
            self.trading_day_count % self.p.rebalance_frequency == 0):
            self._perform_stock_selection(current_date)
        
        # 遍歷所有資料源（股票）
        for i, data in enumerate(self.datas):
            symbol = data._name if hasattr(data, '_name') else f'data{i}'
            
            # 檢查是否有掛單
            if self.orders[symbol] is not None:
                continue
            
            close = data.close[0]
            ind = self.indicators[symbol]
            N = ind['atr'][0]
            
            # [新增] 檢查指標是否準備好
            # 如果 ATR 還是 NaN，代表這支股票剛上市或資料剛開始，不能交易
            if math.isnan(ind['atr'][0]) or math.isnan(ind['s1_high'][0]):
                continue
            
            # 獲取當前持倉
            position = self.getposition(data)
            
            # 如果該股票不在選中列表中
            if symbol not in self.selected_symbols:
                # 如果有持倉，繼續執行出場邏輯（停損、技術指標出場）
                # 但不再建立新倉位
                if position:
                    # 執行出場邏輯
                    exit_s1 = close < ind['s1_low_exit'][0]
                    exit_s2 = close < ind['s2_low_exit'][0]
                    exit_stop = self.stop_prices[symbol] is not None and close < self.stop_prices[symbol]
                    
                    if exit_stop or exit_s1 or exit_s2:
                        self.log(
                            f'[{symbol}] EXIT LONG (被踢出選股池), Price: {close:.2f}, '
                            f'Stop: {self.stop_prices[symbol] if self.stop_prices[symbol] is not None else "nan"}, '
                            f'S1Low: {ind["s1_low_exit"][0]:.2f}, '
                            f'S2Low: {ind["s2_low_exit"][0]:.2f}'
                        )
                        self.orders[symbol] = self.close(data=data)
                        self.units[symbol] = 0
                        self.entry_prices[symbol] = None
                        self.stop_prices[symbol] = None
                        self.next_add_prices[symbol] = None
                # 如果沒有持倉，直接跳過（不建立新倉位）
                continue
            
            # 1) 沒有持倉 → 找入場機會（只有在選中列表中才會執行）
            if not position:
                self.units[symbol] = 0
                self.entry_prices[symbol] = None
                self.stop_prices[symbol] = None
                self.next_add_prices[symbol] = None

                # 只要任一系統出現「向上突破」訊號就建立多單
                long_signal_s1 = close > ind['s1_high'][0]
                long_signal_s2 = close > ind['s2_high'][0]

                # 檢查 N 是否有效（不是 None、NaN 且 > 0）
                if (long_signal_s1 or long_signal_s2) and N is not None and not pd.isna(N) and N > 0:
                    size = self._calc_unit_size(symbol)
                    if size <= 0:
                        continue  # 資金或 N 不適合開倉

                    # 確保 size 是整數（股數不可分割）
                    size = int(size)
                    
                    # 建立第一個 unit
                    self.orders[symbol] = self.buy(data=data, size=size)
                    self.units[symbol] = 1
                    self.entry_prices[symbol] = close

                    # 初始停損價：入場價 - 2N
                    self.stop_prices[symbol] = self.entry_prices[symbol] - self.p.atr_mult_stop * N

                    # 下一次加碼價：入場價 + 0.5N
                    self.next_add_prices[symbol] = self.entry_prices[symbol] + self.p.atr_step_pyramid * N

                    self.log(
                        f'[{symbol}] ENTRY LONG, Price: {close:.2f}, Size: {size}, '
                        f'N: {N:.2f}, Stop: {self.stop_prices[symbol]:.2f}, '
                        f'Next Add: {self.next_add_prices[symbol]:.2f}'
                    )

            # 2) 已經有多頭部位 → 管理出場 & 加碼
            else:
                # 出場條件：
                # a) 跌破停損價
                # b) 系統1：跌破 10 日低點
                # c) 系統2：跌破 20 日低點
                exit_s1 = close < ind['s1_low_exit'][0]
                exit_s2 = close < ind['s2_low_exit'][0]
                exit_stop = self.stop_prices[symbol] is not None and close < self.stop_prices[symbol]

                if exit_stop or exit_s1 or exit_s2:
                    self.log(
                        f'[{symbol}] EXIT LONG, Price: {close:.2f}, '
                        f'Stop: {self.stop_prices[symbol] if self.stop_prices[symbol] is not None else "nan"}, '
                        f'S1Low: {ind["s1_low_exit"][0]:.2f}, '
                        f'S2Low: {ind["s2_low_exit"][0]:.2f}'
                    )
                    self.orders[symbol] = self.close(data=data)
                    self.units[symbol] = 0
                    self.entry_prices[symbol] = None
                    self.stop_prices[symbol] = None
                    self.next_add_prices[symbol] = None
                    continue  # 出場後本 bar 不再加碼

                # 加碼邏輯：只在順勢 & 未達 max_units 時加碼
                if (
                    self.units[symbol] > 0
                    and self.units[symbol] < self.p.max_units
                    and self.next_add_prices[symbol] is not None
                    and N is not None
                    and not pd.isna(N)
                    and N > 0
                ):
                    # 價格已經走到加碼價以上 → 再買一個 unit
                    if close >= self.next_add_prices[symbol]:
                        size = self._calc_unit_size(symbol)
                        if size > 0:
                            # 確保 size 是整數（股數不可分割）
                            size = int(size)
                            self.orders[symbol] = self.buy(data=data, size=size)
                            self.units[symbol] += 1

                            # 設定下一階加碼價：在上一階基礎上再 +0.5N
                            self.next_add_prices[symbol] = self.next_add_prices[symbol] + self.p.atr_step_pyramid * N

                            self.log(
                                f'[{symbol}] PYRAMID ADD, Price: {close:.2f}, Size: {size}, '
                                f'Units: {self.units[symbol]}, Next Add: {self.next_add_prices[symbol]:.2f}'
                            )

# %%
import backtrader as bt
from datetime import datetime, timedelta

# ===== 1. 設定回測參數 =====
# 回測期間：2024-01-01 到 2024-12-31
BACKTEST_START = '2024-01-01'
BACKTEST_END = '2024-12-31'

# 選股需要一個月前的資料，所以資料下載期間要往前推一個月
DATA_START = (datetime.strptime(BACKTEST_START, '%Y-%m-%d') - timedelta(days=30)).strftime('%Y-%m-%d')
DATA_END = BACKTEST_END

print("=" * 60)
print("步驟 1: 下載台灣所有股票資料（包含選股所需的歷史資料）")
print("=" * 60)

# ===== 2. 下載台灣所有股票資料 =====
# 下載從一個月前到回測結束的所有資料（用於選股）
full_data_manager = StockDataManager(
    country_code='TW',
    start_date=DATA_START,
    end_date=DATA_END
)
# Out:
# ============================================================
# 步驟 1: 下載台灣所有股票資料（包含選股所需的歷史資料）
# ============================================================
# 正在從台灣證交所 API 抓取股票代號...
# 成功抓取 1321 檔台灣股票代號
# 正在使用 yfinance 下載 1321 檔股票資料...
# 正在下載第 1 批（共 100 檔）...
# 正在下載第 2 批（共 100 檔）...
# 21 Failed downloads:
# ['00981T.TW', '009803.TW', '009800.TW', '009808.TW', '009805.TW', '009804.TW', '00980A.TW', '00981A.TW', '00982D.TW', '00983D.TW', '009810.TW', '00984A.TW', '009813.TW', '009812.TW', '009809.TW', '00985A.TW', '00983A.TW', '009801.TW', '009811.TW', '009802.TW', '00982A.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 3 批（共 100 檔）...
# 20 Failed downloads:
# ['020031.TW', '020012.TW', '02001R.TW', '020030.TW', '020011.TW', '020034.TW', '020000.TW', '020037.TW', '020020.TW', '02001L.TW', '020029.TW', '020036.TW', '020039.TW', '02001S.TW', '020038.TW', '020028.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31)')
# ['00988A.TW', '00989A.TW', '00985B.TW', '00986A.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 4 批（共 100 檔）...
# 正在下載第 5 批（共 100 檔）...
# 1 Failed download:
# ['2248.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 6 批（共 100 檔）...
# 正在下載第 7 批（共 100 檔）...
# 正在下載第 8 批（共 100 檔）...
# 3 Failed downloads:
# ['2887I.TW', '2887G.TW', '2887H.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 9 批（共 100 檔）...
# 1 Failed download:
# ['3717.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 10 批（共 100 檔）...
# 2 Failed downloads:
# ['4585.TW', '4441.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 11 批（共 100 檔）...
# 正在下載第 12 批（共 100 檔）...
# 8 Failed downloads:
# ['6918.TW', '6589.TW', '6965.TW', '6887.TW', '6909.TW', '7610.TW', '6944.TW', '6936.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 13 批（共 100 檔）...
# 7 Failed downloads:
# ['7740.TW', '7736.TW', '7788.TW', '7780.TW', '7786.TW', '7750.TW', '7749.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1701446400, endDate = 1735574400")')
# 正在下載第 14 批（共 21 檔）...
# ------------------------------
# 已成功下載 1321 檔股票資料
#   - 0050.TW: 261 筆資料，日期範圍 2023-12-04 至 2024-12-30
#   - 0051.TW: 261 筆資料，日期範圍 2023-12-04 至 2024-12-30
#   - 0053.TW: 261 筆資料，日期範圍 2023-12-04 至 2024-12-30
#   - 0055.TW: 261 筆資料，日期範圍 2023-12-04 至 2024-12-30
#   - 0056.TW: 261 筆資料，日期範圍 2023-12-04 至 2024-12-30
#   ... 還有 1316 檔股票
# ------------------------------

# %%
print("\n" + "=" * 60)
print("步驟 2: 切出回測期間的資料給 backtrader")
print("=" * 60)

# ===== 3. 切出回測期間的資料 =====
# 從完整資料中切出回測期間的資料
backtest_data_manager = full_data_manager.subset(BACKTEST_START, BACKTEST_END)

print(f"\n回測期間資料: {len(backtest_data_manager.stock_data)} 檔股票")

# ===== 4. 設定 backtrader =====
cerebro = bt.Cerebro()

added_count = 0
for symbol, df in backtest_data_manager.stock_data.items():
    if df.empty:
        continue
    try:
        # 1. 確保索引格式
        if not isinstance(df.index, pd.DatetimeIndex):
            df.index = pd.to_datetime(df.index)
        
        # [新增] 2. 資料清洗：非常重要！
        # 填補空缺值 (Forward Fill)，如果還有 NaN 則刪除該行
        df = df.ffill().dropna()

        # [新增] 3. 檢查資料長度
        # 如果資料少於策略需要的最小天數 (例如 55 天)，直接跳過，不然指標算不出來會報錯
        if len(df) < 60: 
            print(f"跳過 {symbol}: 資料長度不足 ({len(df)} days)")
            continue

        required_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
        if all(col in df.columns for col in required_cols):
            datafeed = bt.feeds.PandasData(
                dataname=df,
                datetime=None,
                open=0, high=1, low=2, close=3, volume=4,
                openinterest=-1
            )
            datafeed._name = symbol
            cerebro.adddata(datafeed)
            added_count += 1
            
    except Exception as e:
        print(f"警告: 無法添加 {symbol} 的資料: {e}")
        continue

print(f"\n成功添加 {added_count} 檔股票的資料到 backtrader")

# ===== 5. 添加策略 =====
cerebro.addstrategy(
    TurtleLongWithSelection,
    selection_data_manager=full_data_manager,  # 傳入完整資料管理器（用於選股）
    selection_lookback_days=30,  # 選股回測時間：30天
    rebalance_frequency=1,  # 每個交易日都重新選股
)

# ===== 6. 設定經紀商參數 =====
cerebro.broker.setcash(1000000.0)  # 初始資金 100 萬
cerebro.broker.setcommission(commission=0.001)  # 手續費 0.1%

# ===== 7. 執行回測 =====
print("\n" + "=" * 60)
print("步驟 3: 執行回測")
print("=" * 60)
print(f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')

cerebro.run()

print(f'\nFinal Portfolio Value: {cerebro.broker.getvalue():.2f}')
print(f'Total Return: {(cerebro.broker.getvalue() / 1000000.0 - 1) * 100:.2f}%')
# Out:
# ============================================================
# 步驟 2: 切出回測期間的資料給 backtrader
# ============================================================
#
# 回測期間資料: 1321 檔股票
# 跳過 00938.TW: 資料長度不足 (55 days)
# 跳過 00961.TW: 資料長度不足 (59 days)
# 跳過 00962.TW: 資料長度不足 (24 days)
# 跳過 00963.TW: 資料長度不足 (33 days)
# 跳過 00964.TW: 資料長度不足 (33 days)
# 跳過 00965.TW: 資料長度不足 (36 days)
# 跳過 00971.TW: 資料長度不足 (2 days)
# 跳過 00972.TW: 資料長度不足 (1 days)
# 跳過 009800.TW: 資料長度不足 (0 days)
# 跳過 009801.TW: 資料長度不足 (0 days)
# 跳過 009802.TW: 資料長度不足 (0 days)
# 跳過 009803.TW: 資料長度不足 (0 days)
# 跳過 009804.TW: 資料長度不足 (0 days)
# 跳過 009805.TW: 資料長度不足 (0 days)
# 跳過 009808.TW: 資料長度不足 (0 days)
# 跳過 009809.TW: 資料長度不足 (0 days)
# 跳過 00980A.TW: 資料長度不足 (0 days)
# 跳過 009810.TW: 資料長度不足 (0 days)
# 跳過 009811.TW: 資料長度不足 (0 days)
# 跳過 009812.TW: 資料長度不足 (0 days)
# 跳過 009813.TW: 資料長度不足 (0 days)
# 跳過 00981A.TW: 資料長度不足 (0 days)
# 跳過 00981T.TW: 資料長度不足 (0 days)
# 跳過 00982A.TW: 資料長度不足 (0 days)
# 跳過 00982D.TW: 資料長度不足 (0 days)
# 跳過 00983A.TW: 資料長度不足 (0 days)
# 跳過 00983D.TW: 資料長度不足 (0 days)
# 跳過 00984A.TW: 資料長度不足 (0 days)
# 跳過 00985A.TW: 資料長度不足 (0 days)
# 跳過 00985B.TW: 資料長度不足 (0 days)
# 跳過 00986A.TW: 資料長度不足 (0 days)
# 跳過 00988A.TW: 資料長度不足 (0 days)
# 跳過 00989A.TW: 資料長度不足 (0 days)
# 跳過 020000.TW: 資料長度不足 (0 days)
# 跳過 020011.TW: 資料長度不足 (0 days)
# 跳過 020012.TW: 資料長度不足 (0 days)
# 跳過 02001L.TW: 資料長度不足 (0 days)
# 跳過 02001R.TW: 資料長度不足 (0 days)
# 跳過 02001S.TW: 資料長度不足 (0 days)
# 跳過 020020.TW: 資料長度不足 (0 days)
# 跳過 020028.TW: 資料長度不足 (0 days)
# 跳過 020029.TW: 資料長度不足 (0 days)
# 跳過 020030.TW: 資料長度不足 (0 days)
# 跳過 020031.TW: 資料長度不足 (0 days)
# 跳過 020034.TW: 資料長度不足 (0 days)
# 跳過 020036.TW: 資料長度不足 (0 days)
# 跳過 020037.TW: 資料長度不足 (0 days)
# 跳過 020038.TW: 資料長度不足 (0 days)
# 跳過 020039.TW: 資料長度不足 (0 days)
# 跳過 2248.TW: 資料長度不足 (0 days)
# 跳過 2646.TW: 資料長度不足 (53 days)
# 跳過 2887G.TW: 資料長度不足 (0 days)
# 跳過 2887H.TW: 資料長度不足 (0 days)
# 跳過 2887I.TW: 資料長度不足 (0 days)
# 跳過 3717.TW: 資料長度不足 (0 days)
# 跳過 4441.TW: 資料長度不足 (0 days)
# 跳過 4585.TW: 資料長度不足 (0 days)
# 跳過 6589.TW: 資料長度不足 (0 days)
# 跳過 6862.TW: 資料長度不足 (48 days)
# 跳過 6885.TW: 資料長度不足 (16 days)
# 跳過 6887.TW: 資料長度不足 (0 days)
# 跳過 6909.TW: 資料長度不足 (0 days)
# 跳過 6918.TW: 資料長度不足 (0 days)
# 跳過 6924.TW: 資料長度不足 (27 days)
# 跳過 6936.TW: 資料長度不足 (0 days)
# 跳過 6944.TW: 資料長度不足 (0 days)
# 跳過 6962.TW: 資料長度不足 (25 days)
# 跳過 6965.TW: 資料長度不足 (0 days)
# 跳過 6988.TW: 資料長度不足 (48 days)
# 跳過 7610.TW: 資料長度不足 (0 days)
# 跳過 7705.TW: 資料長度不足 (31 days)
# 跳過 7711.TW: 資料長度不足 (21 days)
# 跳過 7722.TW: 資料長度不足 (25 days)
# 跳過 7736.TW: 資料長度不足 (0 days)
# 跳過 7740.TW: 資料長度不足 (0 days)
# 跳過 7749.TW: 資料長度不足 (0 days)
# 跳過 7750.TW: 資料長度不足 (0 days)
# 跳過 7780.TW: 資料長度不足 (0 days)
# 跳過 7786.TW: 資料長度不足 (0 days)
# 跳過 7788.TW: 資料長度不足 (0 days)
# 跳過 7791.TW: 資料長度不足 (25 days)
# 跳過 7799.TW: 資料長度不足 (24 days)
#
# 成功添加 1239 檔股票的資料到 backtrader
#
# ============================================================
# 步驟 3: 執行回測
# ============================================================
# Starting Portfolio Value: 1000000.00
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-01 - 選股結果: Picker選出 130 檔 -> 與BT匹配成功 130 檔 (範例: ['6672.TW', '3494.TW', '3416.TW', '1410.TW', '2012.TW'] ...)
# 2024-11-01 - [5515.TW] ENTRY LONG, Price: 25.22, Size: 6819, N: 0.73, Stop: 23.75, Next Add: 25.59
# 2024-11-04 - [5515.TW] BUY EXECUTED, Price: 25.22, Size: 6819, Cost: 171969.00
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-04 - 選股結果: Picker選出 163 檔 -> 與BT匹配成功 163 檔 (範例: ['3494.TW', '3416.TW', '00647L.TW', '1410.TW', '3044.TW'] ...)
# 2024-11-04 - [3701.TW] ENTRY LONG, Price: 48.26, Size: 2693, N: 1.86, Stop: 44.54, Next Add: 49.18
# 2024-11-05 - [3701.TW] BUY EXECUTED, Price: 44.97, Size: 2693, Cost: 121108.84
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-05 - 選股結果: Picker選出 155 檔 -> 與BT匹配成功 155 檔 (範例: ['6672.TW', '3494.TW', '3416.TW', '1410.TW', '3044.TW'] ...)
# 2024-11-05 - [1475.TW] ENTRY LONG, Price: 60.38, Size: 2577, N: 1.94, Stop: 56.51, Next Add: 61.35
# 2024-11-05 - [1531.TW] ENTRY LONG, Price: 16.41, Size: 10613, N: 0.47, Stop: 15.47, Next Add: 16.65
# 2024-11-05 - [1736.TW] ENTRY LONG, Price: 169.04, Size: 547, N: 9.11, Stop: 150.81, Next Add: 173.59
# 2024-11-05 - [3701.TW] EXIT LONG, Price: 44.47, Stop: 44.54248270137617, S1Low: 36.96, S2Low: 36.96
# 2024-11-05 - [9917.TW] ENTRY LONG, Price: 133.38, Size: 1889, N: 2.64, Stop: 128.10, Next Add: 134.70
# 2024-11-06 - [1475.TW] BUY EXECUTED, Price: 60.20, Size: 2577, Cost: 155122.93
# 2024-11-06 - [1531.TW] BUY EXECUTED, Price: 15.30, Size: 10613, Cost: 162362.06
# 2024-11-06 - [1736.TW] BUY EXECUTED, Price: 168.55, Size: 547, Cost: 92196.76
# 2024-11-06 - [3701.TW] SELL EXECUTED, Price: 49.45, Size: -2693, Cost: 121108.84
# 2024-11-06 - [9917.TW] BUY EXECUTED, Price: 133.38, Size: 1889, Cost: 251951.95
# 2024-11-06 - [3701.TW] TRADE PROFIT, Gross: 12057.30, Net: 11803.03
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-06 - 選股結果: Picker選出 154 檔 -> 與BT匹配成功 154 檔 (範例: ['6672.TW', '3494.TW', '1410.TW', '3044.TW', '1582.TW'] ...)
# 2024-11-06 - [2705.TW] ENTRY LONG, Price: 18.15, Size: 15937, N: 0.32, Stop: 17.51, Next Add: 18.31
# 2024-11-06 - [8261.TW] ENTRY LONG, Price: 88.85, Size: 1560, N: 3.25, Stop: 82.34, Next Add: 90.48
# 2024-11-07 - [2705.TW] Order Canceled/Margin/Rejected
# 2024-11-07 - [8261.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-07 - 選股結果: Picker選出 155 檔 -> 與BT匹配成功 155 檔 (範例: ['6674.TW', '00850.TW', '1410.TW', '3044.TW', '1582.TW'] ...)
# 2024-11-07 - [00757.TW] ENTRY LONG, Price: 94.30, Size: 3543, N: 1.43, Stop: 91.45, Next Add: 95.01
# 2024-11-07 - [00762.TW] ENTRY LONG, Price: 66.50, Size: 4915, N: 1.03, Stop: 64.45, Next Add: 67.01
# 2024-11-07 - [00851.TW] ENTRY LONG, Price: 47.08, Size: 8984, N: 0.56, Stop: 45.95, Next Add: 47.36
# 2024-11-07 - [00895.TW] ENTRY LONG, Price: 30.96, Size: 10425, N: 0.48, Stop: 29.99, Next Add: 31.20
# 2024-11-07 - [00910.TW] ENTRY LONG, Price: 25.25, Size: 11466, N: 0.44, Stop: 24.37, Next Add: 25.47
# 2024-11-07 - [00953B.TW] ENTRY LONG, Price: 9.31, Size: 126975, N: 0.04, Stop: 9.23, Next Add: 9.33
# 2024-11-07 - [1531.TW] EXIT LONG (被踢出選股池), Price: 15.40, Stop: 15.471220543632466, S1Low: 13.70, S2Low: 13.60
# 2024-11-07 - [2331.TW] ENTRY LONG, Price: 25.01, Size: 6530, N: 0.77, Stop: 23.46, Next Add: 25.39
# 2024-11-07 - [3014.TW] ENTRY LONG, Price: 142.95, Size: 1100, N: 4.59, Stop: 133.77, Next Add: 145.24
# 2024-11-08 - [00757.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [00762.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [00851.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [00895.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [00910.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [00953B.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [1531.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [2331.TW] Order Canceled/Margin/Rejected
# 2024-11-08 - [3014.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-08 - 選股結果: Picker選出 155 檔 -> 與BT匹配成功 155 檔 (範例: ['6674.TW', '00850.TW', '00638R.TW', '1410.TW', '3044.TW'] ...)
# 2024-11-08 - [006203.TW] ENTRY LONG, Price: 91.64, Size: 4073, N: 1.27, Stop: 89.10, Next Add: 92.27
# 2024-11-08 - [00670L.TW] ENTRY LONG, Price: 136.75, Size: 1688, N: 3.06, Stop: 130.63, Next Add: 138.28
# 2024-11-08 - [00690.TW] ENTRY LONG, Price: 32.98, Size: 9766, N: 0.53, Stop: 31.92, Next Add: 33.24
# 2024-11-08 - [00737.TW] ENTRY LONG, Price: 33.00, Size: 10941, N: 0.47, Stop: 32.06, Next Add: 33.24
# 2024-11-08 - [00757.TW] ENTRY LONG, Price: 96.35, Size: 3509, N: 1.47, Stop: 93.41, Next Add: 97.09
# 2024-11-08 - [00762.TW] ENTRY LONG, Price: 67.55, Size: 4949, N: 1.04, Stop: 65.46, Next Add: 68.07
# 2024-11-08 - [00850.TW] ENTRY LONG, Price: 44.30, Size: 6771, N: 0.76, Stop: 42.78, Next Add: 44.68
# 2024-11-08 - [00851.TW] ENTRY LONG, Price: 48.00, Size: 8903, N: 0.58, Stop: 46.84, Next Add: 48.29
# 2024-11-08 - [00878.TW] ENTRY LONG, Price: 21.02, Size: 19827, N: 0.26, Stop: 20.50, Next Add: 21.15
# 2024-11-08 - [00893.TW] ENTRY LONG, Price: 24.48, Size: 11898, N: 0.43, Stop: 23.61, Next Add: 24.70
# 2024-11-08 - [00895.TW] ENTRY LONG, Price: 31.34, Size: 10700, N: 0.48, Stop: 30.37, Next Add: 31.58
# 2024-11-08 - [00896.TW] ENTRY LONG, Price: 16.64, Size: 18790, N: 0.27, Stop: 16.09, Next Add: 16.78
# 2024-11-08 - [00897.TW] ENTRY LONG, Price: 8.60, Size: 50873, N: 0.10, Stop: 8.40, Next Add: 8.65
# 2024-11-08 - [00901.TW] ENTRY LONG, Price: 21.13, Size: 12697, N: 0.41, Stop: 20.31, Next Add: 21.33
# 2024-11-08 - [00910.TW] ENTRY LONG, Price: 25.76, Size: 11635, N: 0.44, Stop: 24.87, Next Add: 25.98
# 2024-11-08 - [00916.TW] ENTRY LONG, Price: 23.76, Size: 21426, N: 0.24, Stop: 23.27, Next Add: 23.88
# 2024-11-08 - [00922.TW] ENTRY LONG, Price: 20.41, Size: 14724, N: 0.35, Stop: 19.71, Next Add: 20.58
# 2024-11-08 - [1220.TW] ENTRY LONG, Price: 16.68, Size: 16399, N: 0.31, Stop: 16.05, Next Add: 16.83
# 2024-11-08 - [1795.TW] ENTRY LONG, Price: 262.96, Size: 664, N: 7.77, Stop: 247.42, Next Add: 266.84
# 2024-11-08 - [2545.TW] ENTRY LONG, Price: 56.97, Size: 2485, N: 2.08, Stop: 52.81, Next Add: 58.01
# 2024-11-08 - [3044.TW] ENTRY LONG, Price: 194.24, Size: 943, N: 5.47, Stop: 183.30, Next Add: 196.98
# 2024-11-08 - [3706.TW] ENTRY LONG, Price: 46.76, Size: 3771, N: 1.37, Stop: 44.02, Next Add: 47.44
# 2024-11-08 - [5269.TW] ENTRY LONG, Price: 1795.88, Size: 48, N: 105.80, Stop: 1584.29, Next Add: 1848.78
# 2024-11-11 - [006203.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00670L.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00690.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00737.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00757.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00762.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00850.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00851.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00878.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00893.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00895.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00896.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00897.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00901.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00910.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00916.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [00922.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [1220.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [1795.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [2545.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [3044.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [3706.TW] Order Canceled/Margin/Rejected
# 2024-11-11 - [5269.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-11 - 選股結果: Picker選出 144 檔 -> 與BT匹配成功 144 檔 (範例: ['7631.TW', '00850.TW', '00918.TW', '3044.TW', '2069.TW'] ...)
# 2024-11-11 - [00662.TW] ENTRY LONG, Price: 87.80, Size: 4770, N: 1.06, Stop: 85.69, Next Add: 88.33
# 2024-11-11 - [00670L.TW] ENTRY LONG, Price: 137.30, Size: 1701, N: 2.96, Stop: 131.38, Next Add: 138.78
# 2024-11-11 - [00737.TW] ENTRY LONG, Price: 33.54, Size: 10560, N: 0.48, Stop: 32.59, Next Add: 33.78
# 2024-11-11 - [00851.TW] ENTRY LONG, Price: 48.04, Size: 8943, N: 0.56, Stop: 46.91, Next Add: 48.32
# 2024-11-11 - [1466.TW] ENTRY LONG, Price: 14.70, Size: 8976, N: 0.56, Stop: 13.58, Next Add: 14.98
# 2024-11-11 - [1708.TW] ENTRY LONG, Price: 39.19, Size: 3967, N: 1.27, Stop: 36.65, Next Add: 39.83
# 2024-11-11 - [1795.TW] ENTRY LONG, Price: 280.49, Size: 597, N: 8.43, Stop: 263.64, Next Add: 284.70
# 2024-11-11 - [2506.TW] ENTRY LONG, Price: 12.12, Size: 13540, N: 0.37, Stop: 11.37, Next Add: 12.30
# 2024-11-11 - [2520.TW] ENTRY LONG, Price: 44.09, Size: 3159, N: 1.59, Stop: 40.91, Next Add: 44.89
# 2024-11-11 - [2545.TW] ENTRY LONG, Price: 59.98, Size: 2281, N: 2.21, Stop: 55.57, Next Add: 61.09
# 2024-11-11 - [2712.TW] ENTRY LONG, Price: 26.30, Size: 11250, N: 0.45, Stop: 25.40, Next Add: 26.52
# 2024-11-11 - [3706.TW] ENTRY LONG, Price: 53.41, Size: 3083, N: 1.63, Stop: 50.14, Next Add: 54.23
# 2024-11-11 - [5515.TW] EXIT LONG (被踢出選股池), Price: 23.49, Stop: 23.7526904393474, S1Low: 22.86, S2Low: 22.76
# 2024-11-11 - [6781.TW] ENTRY LONG, Price: 691.59, Size: 163, N: 30.85, Stop: 629.89, Next Add: 707.01
# 2024-11-11 - [9937.TW] ENTRY LONG, Price: 64.61, Size: 5636, N: 0.89, Stop: 62.82, Next Add: 65.05
# 2024-11-12 - [00662.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [00670L.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [00737.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [00851.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [1466.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [1708.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [1795.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [2506.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [2520.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [2545.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [2712.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [3706.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [5515.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [6781.TW] Order Canceled/Margin/Rejected
# 2024-11-12 - [9937.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-12 - 選股結果: Picker選出 156 檔 -> 與BT匹配成功 156 檔 (範例: ['7631.TW', '00850.TW', '00647L.TW', '3055.TW', '3044.TW'] ...)
# 2024-11-12 - [00640L.TW] ENTRY LONG, Price: 54.35, Size: 3392, N: 1.46, Stop: 51.42, Next Add: 55.08
# 2024-11-12 - [00865B.TW] ENTRY LONG, Price: 46.22, Size: 22603, N: 0.22, Stop: 45.78, Next Add: 46.33
# 2024-11-12 - [00875.TW] ENTRY LONG, Price: 36.40, Size: 11414, N: 0.43, Stop: 35.53, Next Add: 36.62
# 2024-11-12 - [1466.TW] ENTRY LONG, Price: 15.00, Size: 8857, N: 0.56, Stop: 13.88, Next Add: 15.28
# 2024-11-12 - [1736.TW] EXIT LONG (被踢出選股池), Price: 144.19, Stop: 150.808111612689, S1Low: 141.27, S2Low: 138.35
# 2024-11-12 - [2069.TW] ENTRY LONG, Price: 18.10, Size: 6111, N: 0.81, Stop: 16.48, Next Add: 18.51
# 2024-11-12 - [2387.TW] ENTRY LONG, Price: 53.86, Size: 4291, N: 1.16, Stop: 51.54, Next Add: 54.44
# 2024-11-12 - [8481.TW] ENTRY LONG, Price: 49.81, Size: 7035, N: 0.71, Stop: 48.40, Next Add: 50.16
# 2024-11-13 - [00640L.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [00865B.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [00875.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [1466.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [1736.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [2069.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [2387.TW] Order Canceled/Margin/Rejected
# 2024-11-13 - [8481.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-13 - 選股結果: Picker選出 147 檔 -> 與BT匹配成功 147 檔 (範例: ['6672.TW', '7631.TW', '00850.TW', '00647L.TW', '00918.TW'] ...)
# 2024-11-13 - [00651R.TW] ENTRY LONG, Price: 7.62, Size: 21488, N: 0.23, Stop: 7.17, Next Add: 7.73
# 2024-11-13 - [00666R.TW] ENTRY LONG, Price: 12.53, Size: 12510, N: 0.39, Stop: 11.75, Next Add: 12.72
# 2024-11-13 - [1475.TW] EXIT LONG (被踢出選股池), Price: 55.32, Stop: 56.50558222724153, S1Low: 54.86, S2Low: 54.86
# 2024-11-13 - [1736.TW] EXIT LONG (被踢出選股池), Price: 131.04, Stop: nan, S1Low: 134.94, S2Low: 134.94
# 2024-11-13 - [2945.TW] ENTRY LONG, Price: 40.52, Size: 9024, N: 0.54, Stop: 39.44, Next Add: 40.79
# 2024-11-13 - [4119.TW] ENTRY LONG, Price: 92.70, Size: 3574, N: 1.36, Stop: 89.98, Next Add: 93.38
# 2024-11-13 - [5525.TW] ENTRY LONG, Price: 32.79, Size: 3841, N: 1.26, Stop: 30.26, Next Add: 33.42
# 2024-11-14 - [00666R.TW] Order Canceled/Margin/Rejected
# 2024-11-14 - [1475.TW] Order Canceled/Margin/Rejected
# 2024-11-14 - [2945.TW] Order Canceled/Margin/Rejected
# 2024-11-14 - [4119.TW] Order Canceled/Margin/Rejected
# 2024-11-14 - [5525.TW] Order Canceled/Margin/Rejected
# 2024-11-14 - [00651R.TW] BUY EXECUTED, Price: 7.68, Size: 21488, Cost: 165027.84
# 2024-11-14 - [1736.TW] SELL EXECUTED, Price: 136.40, Size: -547, Cost: 92196.76
# 2024-11-14 - [1736.TW] TRADE PROFIT, Gross: -17586.66, Net: -17753.47
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-14 - 選股結果: Picker選出 122 檔 -> 與BT匹配成功 122 檔 (範例: ['6672.TW', '6674.TW', '00647L.TW', '00918.TW', '00640L.TW'] ...)
# 2024-11-14 - [00674R.TW] ENTRY LONG, Price: 9.83, Size: 43734, N: 0.11, Stop: 9.61, Next Add: 9.88
# 2024-11-14 - [1471.TW] ENTRY LONG, Price: 14.85, Size: 8471, N: 0.57, Stop: 13.71, Next Add: 15.13
# 2024-11-14 - [2404.TW] ENTRY LONG, Price: 365.80, Size: 420, N: 11.43, Stop: 342.94, Next Add: 371.52
# 2024-11-14 - [6472.TW] ENTRY LONG, Price: 651.90, Size: 241, N: 19.93, Stop: 612.03, Next Add: 661.86
# 2024-11-14 - [6558.TW] ENTRY LONG, Price: 25.33, Size: 5505, N: 0.87, Stop: 23.58, Next Add: 25.77
# 2024-11-14 - [910861.TW] ENTRY LONG, Price: 6.13, Size: 21343, N: 0.23, Stop: 5.68, Next Add: 6.24
# 2024-11-15 - [00674R.TW] Order Canceled/Margin/Rejected
# 2024-11-15 - [1471.TW] Order Canceled/Margin/Rejected
# 2024-11-15 - [2404.TW] Order Canceled/Margin/Rejected
# 2024-11-15 - [6472.TW] Order Canceled/Margin/Rejected
# 2024-11-15 - [6558.TW] Order Canceled/Margin/Rejected
# 2024-11-15 - [910861.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-15 - 選股結果: Picker選出 113 檔 -> 與BT匹配成功 113 檔 (範例: ['6165.TW', '6674.TW', '00918.TW', '3419.TW', '912000.TW'] ...)
# 2024-11-15 - [00666R.TW] ENTRY LONG, Price: 12.80, Size: 13159, N: 0.37, Stop: 12.06, Next Add: 12.99
# 2024-11-15 - [1475.TW] EXIT LONG, Price: 53.03, Stop: nan, S1Low: 53.30, S2Low: 53.30
# 2024-11-15 - [1524.TW] ENTRY LONG, Price: 36.17, Size: 3801, N: 1.28, Stop: 33.61, Next Add: 36.82
# 2024-11-15 - [2945.TW] ENTRY LONG, Price: 40.66, Size: 8634, N: 0.57, Stop: 39.53, Next Add: 40.95
# 2024-11-15 - [3090.TW] ENTRY LONG, Price: 65.82, Size: 2929, N: 1.67, Stop: 62.49, Next Add: 66.66
# 2024-11-15 - [6558.TW] ENTRY LONG, Price: 27.52, Size: 5077, N: 0.96, Stop: 25.59, Next Add: 28.00
# 2024-11-15 - [9917.TW] EXIT LONG, Price: 129.08, Stop: 128.09564337626108, S1Low: 129.08, S2Low: 129.08
# 2024-11-18 - [00666R.TW] Order Canceled/Margin/Rejected
# 2024-11-18 - [1524.TW] Order Canceled/Margin/Rejected
# 2024-11-18 - [2945.TW] Order Canceled/Margin/Rejected
# 2024-11-18 - [3090.TW] Order Canceled/Margin/Rejected
# 2024-11-18 - [6558.TW] Order Canceled/Margin/Rejected
# 2024-11-18 - [9917.TW] Order Canceled/Margin/Rejected
# 2024-11-18 - [1475.TW] SELL EXECUTED, Price: 53.03, Size: -2577, Cost: 155122.93
# 2024-11-18 - [1475.TW] TRADE PROFIT, Gross: -18472.65, Net: -18764.42
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-18 - 選股結果: Picker選出 99 檔 -> 與BT匹配成功 99 檔 (範例: ['2348.TW', '6674.TW', '00918.TW', '912000.TW', '4958.TW'] ...)
# 2024-11-18 - [00673R.TW] ENTRY LONG, Price: 7.80, Size: 32799, N: 0.15, Stop: 7.51, Next Add: 7.87
# 2024-11-18 - [1442.TW] ENTRY LONG, Price: 66.62, Size: 1787, N: 2.70, Stop: 61.22, Next Add: 67.97
# 2024-11-18 - [1730.TW] ENTRY LONG, Price: 50.67, Size: 13714, N: 0.35, Stop: 49.97, Next Add: 50.85
# 2024-11-18 - [9917.TW] EXIT LONG, Price: 127.16, Stop: nan, S1Low: 127.16, S2Low: 127.16
# 2024-11-19 - [00673R.TW] Order Canceled/Margin/Rejected
# 2024-11-19 - [1442.TW] Order Canceled/Margin/Rejected
# 2024-11-19 - [1730.TW] Order Canceled/Margin/Rejected
# 2024-11-19 - [9917.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-19 - 選股結果: Picker選出 94 檔 -> 與BT匹配成功 94 檔 (範例: ['2348.TW', '1217.TW', '912000.TW', '4958.TW', '1467.TW'] ...)
# 2024-11-19 - [1210.TW] ENTRY LONG, Price: 49.97, Size: 7314, N: 0.65, Stop: 48.66, Next Add: 50.30
# 2024-11-19 - [2945.TW] ENTRY LONG, Price: 41.00, Size: 8082, N: 0.59, Stop: 39.82, Next Add: 41.30
# 2024-11-19 - [3032.TW] ENTRY LONG, Price: 71.26, Size: 1600, N: 2.99, Stop: 65.28, Next Add: 72.76
# 2024-11-20 - [1210.TW] Order Canceled/Margin/Rejected
# 2024-11-20 - [2945.TW] Order Canceled/Margin/Rejected
# 2024-11-20 - [3032.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-20 - 選股結果: Picker選出 94 檔 -> 與BT匹配成功 94 檔 (範例: ['1217.TW', '00638R.TW', '1725.TW', '912000.TW', '4958.TW'] ...)
# 2024-11-20 - [00960.TW] ENTRY LONG, Price: 14.44, Size: 19312, N: 0.25, Stop: 13.94, Next Add: 14.57
# 2024-11-20 - [2332.TW] ENTRY LONG, Price: 21.52, Size: 5617, N: 0.86, Stop: 19.81, Next Add: 21.95
# 2024-11-20 - [8101.TW] ENTRY LONG, Price: 11.45, Size: 38490, N: 0.12, Stop: 11.20, Next Add: 11.51
# 2024-11-21 - [00960.TW] Order Canceled/Margin/Rejected
# 2024-11-21 - [2332.TW] Order Canceled/Margin/Rejected
# 2024-11-21 - [8101.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-21 - 選股結果: Picker選出 92 檔 -> 與BT匹配成功 92 檔 (範例: ['1725.TW', '00638R.TW', '00918.TW', '912000.TW', '9908.TW'] ...)
# 2024-11-21 - [00702.TW] ENTRY LONG, Price: 24.44, Size: 37796, N: 0.13, Stop: 24.19, Next Add: 24.50
# 2024-11-21 - [1312A.TW] ENTRY LONG, Price: 23.50, Size: 31998, N: 0.15, Stop: 23.20, Next Add: 23.57
# 2024-11-21 - [1413.TW] ENTRY LONG, Price: 10.20, Size: 27977, N: 0.17, Stop: 9.86, Next Add: 10.29
# 2024-11-22 - [00702.TW] Order Canceled/Margin/Rejected
# 2024-11-22 - [1312A.TW] Order Canceled/Margin/Rejected
# 2024-11-22 - [1413.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-22 - 選股結果: Picker選出 100 檔 -> 與BT匹配成功 100 檔 (範例: ['3054.TW', '00638R.TW', '00918.TW', '912000.TW', '9908.TW'] ...)
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-25 - 選股結果: Picker選出 93 檔 -> 與BT匹配成功 93 檔 (範例: ['00638R.TW', '912000.TW', '2540.TW', '00640L.TW', '00625K.TW'] ...)
# 2024-11-25 - [00638R.TW] ENTRY LONG, Price: 8.65, Size: 24279, N: 0.20, Stop: 8.25, Next Add: 8.75
# 2024-11-25 - [00656R.TW] ENTRY LONG, Price: 7.66, Size: 24811, N: 0.20, Stop: 7.27, Next Add: 7.76
# 2024-11-25 - [00701.TW] ENTRY LONG, Price: 25.77, Size: 18481, N: 0.26, Stop: 25.24, Next Add: 25.90
# 2024-11-25 - [00714.TW] ENTRY LONG, Price: 21.86, Size: 21143, N: 0.23, Stop: 21.40, Next Add: 21.97
# 2024-11-25 - [1312A.TW] ENTRY LONG, Price: 23.95, Size: 29893, N: 0.16, Stop: 23.63, Next Add: 24.03
# 2024-11-25 - [1460.TW] ENTRY LONG, Price: 7.36, Size: 47871, N: 0.10, Stop: 7.16, Next Add: 7.41
# 2024-11-25 - [1563.TW] ENTRY LONG, Price: 62.13, Size: 2580, N: 1.88, Stop: 58.37, Next Add: 63.07
# 2024-11-25 - [2233.TW] ENTRY LONG, Price: 194.10, Size: 531, N: 9.13, Stop: 175.85, Next Add: 198.66
# 2024-11-25 - [2501.TW] ENTRY LONG, Price: 24.66, Size: 6826, N: 0.71, Stop: 23.23, Next Add: 25.01
# 2024-11-25 - [2832.TW] ENTRY LONG, Price: 35.18, Size: 13896, N: 0.35, Stop: 34.48, Next Add: 35.35
# 2024-11-25 - [3030.TW] ENTRY LONG, Price: 140.47, Size: 680, N: 7.14, Stop: 126.19, Next Add: 144.04
# 2024-11-25 - [3617.TW] ENTRY LONG, Price: 320.77, Size: 378, N: 12.81, Stop: 295.15, Next Add: 327.18
# 2024-11-25 - [8213.TW] ENTRY LONG, Price: 36.73, Size: 7412, N: 0.65, Stop: 35.42, Next Add: 37.06
# 2024-11-26 - [00656R.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [00701.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [00714.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [1312A.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [1460.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [1563.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [2233.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [2501.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [2832.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [3030.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [3617.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [8213.TW] Order Canceled/Margin/Rejected
# 2024-11-26 - [00638R.TW] BUY EXECUTED, Price: 8.72, Size: 24279, Cost: 211712.89
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-26 - 選股結果: Picker選出 106 檔 -> 與BT匹配成功 106 檔 (範例: ['00638R.TW', '9906.TW', '2540.TW', '00640L.TW', '1734.TW'] ...)
# 2024-11-26 - [00634R.TW] ENTRY LONG, Price: 4.17, Size: 51387, N: 0.09, Stop: 3.98, Next Add: 4.22
# 2024-11-26 - [00638R.TW] PYRAMID ADD, Price: 8.78, Size: 24526, Units: 2, Next Add: 8.85
# 2024-11-26 - [00656R.TW] ENTRY LONG, Price: 7.78, Size: 25105, N: 0.19, Stop: 7.39, Next Add: 7.88
# 2024-11-26 - [2419.TW] ENTRY LONG, Price: 36.05, Size: 3037, N: 1.60, Stop: 32.84, Next Add: 36.85
# 2024-11-26 - [2528.TW] ENTRY LONG, Price: 37.91, Size: 3280, N: 1.48, Stop: 34.95, Next Add: 38.66
# 2024-11-26 - [2547.TW] ENTRY LONG, Price: 10.72, Size: 16461, N: 0.30, Stop: 10.13, Next Add: 10.87
# 2024-11-26 - [2832.TW] ENTRY LONG, Price: 35.24, Size: 13771, N: 0.35, Stop: 34.53, Next Add: 35.42
# 2024-11-26 - [3617.TW] ENTRY LONG, Price: 340.17, Size: 363, N: 13.38, Stop: 313.41, Next Add: 346.86
# 2024-11-26 - [6282.TW] ENTRY LONG, Price: 34.65, Size: 3528, N: 1.38, Stop: 31.89, Next Add: 35.34
# 2024-11-26 - [6534.TW] ENTRY LONG, Price: 79.80, Size: 4206, N: 1.16, Stop: 77.49, Next Add: 80.38
# 2024-11-26 - [6592A.TW] ENTRY LONG, Price: 91.07, Size: 50079, N: 0.10, Stop: 90.88, Next Add: 91.12
# 2024-11-27 - [00634R.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [00638R.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [00656R.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [2419.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [2528.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [2547.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [2832.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [3617.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [6282.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [6534.TW] Order Canceled/Margin/Rejected
# 2024-11-27 - [6592A.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-27 - 選股結果: Picker選出 98 檔 -> 與BT匹配成功 98 檔 (範例: ['9906.TW', '2540.TW', '6205.TW', '00640L.TW', '00642U.TW'] ...)
# 2024-11-27 - [2897B.TW] ENTRY LONG, Price: 11.61, Size: 86468, N: 0.06, Stop: 11.50, Next Add: 11.64
# 2024-11-27 - [4562.TW] ENTRY LONG, Price: 76.00, Size: 1120, N: 4.34, Stop: 67.32, Next Add: 78.17
# 2024-11-27 - [8163.TW] ENTRY LONG, Price: 54.22, Size: 2558, N: 1.90, Stop: 50.42, Next Add: 55.17
# 2024-11-28 - [2897B.TW] Order Canceled/Margin/Rejected
# 2024-11-28 - [4562.TW] Order Canceled/Margin/Rejected
# 2024-11-28 - [8163.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-28 - 選股結果: Picker選出 105 檔 -> 與BT匹配成功 105 檔 (範例: ['2540.TW', '3661.TW', '6205.TW', '5225.TW', '3046.TW'] ...)
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-11-29 - 選股結果: Picker選出 104 檔 -> 與BT匹配成功 104 檔 (範例: ['3661.TW', '6205.TW', '2535.TW', '5225.TW', '3046.TW'] ...)
# 2024-11-29 - [01007T.TW] ENTRY LONG, Price: 15.41, Size: 28231, N: 0.17, Stop: 15.07, Next Add: 15.50
# 2024-11-29 - [1470.TW] ENTRY LONG, Price: 20.16, Size: 9034, N: 0.54, Stop: 19.08, Next Add: 20.43
# 2024-11-29 - [5244.TW] ENTRY LONG, Price: 50.07, Size: 3550, N: 1.37, Stop: 47.33, Next Add: 50.76
# 2024-11-29 - [9917.TW] EXIT LONG (被踢出選股池), Price: 122.86, Stop: nan, S1Low: 123.34, S2Low: 123.34
# 2024-12-02 - [01007T.TW] Order Canceled/Margin/Rejected
# 2024-12-02 - [1470.TW] Order Canceled/Margin/Rejected
# 2024-12-02 - [5244.TW] Order Canceled/Margin/Rejected
# 2024-12-02 - [9917.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-02 - 選股結果: Picker選出 111 檔 -> 與BT匹配成功 111 檔 (範例: ['1217.TW', '912000.TW', '2012.TW', '2535.TW', '1315.TW'] ...)
# 2024-12-02 - [1470.TW] ENTRY LONG, Price: 20.68, Size: 8974, N: 0.54, Stop: 19.60, Next Add: 20.95
# 2024-12-02 - [1720.TW] ENTRY LONG, Price: 61.97, Size: 4872, N: 0.99, Stop: 59.99, Next Add: 62.46
# 2024-12-02 - [2748.TW] ENTRY LONG, Price: 59.51, Size: 3312, N: 1.46, Stop: 56.59, Next Add: 60.24
# 2024-12-02 - [5244.TW] ENTRY LONG, Price: 50.36, Size: 3068, N: 1.57, Stop: 47.22, Next Add: 51.15
# 2024-12-02 - [6805.TW] ENTRY LONG, Price: 917.95, Size: 120, N: 40.17, Stop: 837.61, Next Add: 938.04
# 2024-12-03 - [1470.TW] Order Canceled/Margin/Rejected
# 2024-12-03 - [1720.TW] Order Canceled/Margin/Rejected
# 2024-12-03 - [2748.TW] Order Canceled/Margin/Rejected
# 2024-12-03 - [5244.TW] Order Canceled/Margin/Rejected
# 2024-12-03 - [6805.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-03 - 選股結果: Picker選出 125 檔 -> 與BT匹配成功 124 檔 (範例: ['00706L.TW', '1217.TW', '912000.TW', '2012.TW', '2535.TW'] ...)
# 2024-12-03 - [00680L.TW] ENTRY LONG, Price: 8.58, Size: 35963, N: 0.14, Stop: 8.31, Next Add: 8.65
# 2024-12-03 - [00688L.TW] ENTRY LONG, Price: 8.54, Size: 37366, N: 0.13, Stop: 8.28, Next Add: 8.60
# 2024-12-03 - [00861.TW] ENTRY LONG, Price: 43.50, Size: 9529, N: 0.51, Stop: 42.48, Next Add: 43.75
# 2024-12-03 - [3528.TW] ENTRY LONG, Price: 49.79, Size: 5757, N: 0.84, Stop: 48.11, Next Add: 50.21
# 2024-12-03 - [3533.TW] ENTRY LONG, Price: 1938.38, Size: 49, N: 98.99, Stop: 1740.40, Next Add: 1987.87
# 2024-12-03 - [4763.TW] ENTRY LONG, Price: 85.19, Size: 1699, N: 2.86, Stop: 79.48, Next Add: 86.62
# 2024-12-03 - [4912.TW] ENTRY LONG, Price: 114.61, Size: 1105, N: 4.39, Stop: 105.83, Next Add: 116.80
# 2024-12-03 - [6005.TW] ENTRY LONG, Price: 22.18, Size: 9941, N: 0.49, Stop: 21.21, Next Add: 22.43
# 2024-12-03 - [6670.TW] ENTRY LONG, Price: 303.90, Size: 523, N: 9.27, Stop: 285.35, Next Add: 308.54
# 2024-12-03 - [6792.TW] ENTRY LONG, Price: 66.08, Size: 2078, N: 2.34, Stop: 61.41, Next Add: 67.25
# 2024-12-03 - [6805.TW] ENTRY LONG, Price: 947.72, Size: 113, N: 42.63, Stop: 862.47, Next Add: 969.04
# 2024-12-04 - [00680L.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [00688L.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [00861.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [3528.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [3533.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [4763.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [4912.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [6005.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [6670.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [6792.TW] Order Canceled/Margin/Rejected
# 2024-12-04 - [6805.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-04 - 選股結果: Picker選出 119 檔 -> 與BT匹配成功 118 檔 (範例: ['00706L.TW', '1217.TW', '912000.TW', '2535.TW', '1315.TW'] ...)
# 2024-12-04 - [00670L.TW] ENTRY LONG, Price: 137.95, Size: 1938, N: 2.50, Stop: 132.95, Next Add: 139.20
# 2024-12-04 - [1231.TW] ENTRY LONG, Price: 109.15, Size: 2100, N: 2.31, Stop: 104.54, Next Add: 110.31
# 2024-12-04 - [2236.TW] ENTRY LONG, Price: 129.50, Size: 821, N: 5.90, Stop: 117.71, Next Add: 132.45
# 2024-12-04 - [2884.TW] ENTRY LONG, Price: 26.64, Size: 10808, N: 0.45, Stop: 25.75, Next Add: 26.87
# 2024-12-04 - [4912.TW] ENTRY LONG, Price: 124.00, Size: 1007, N: 4.80, Stop: 114.39, Next Add: 126.41
# 2024-12-04 - [6805.TW] ENTRY LONG, Price: 1027.11, Size: 104, N: 46.45, Stop: 934.21, Next Add: 1050.34
# 2024-12-05 - [00670L.TW] Order Canceled/Margin/Rejected
# 2024-12-05 - [1231.TW] Order Canceled/Margin/Rejected
# 2024-12-05 - [2236.TW] Order Canceled/Margin/Rejected
# 2024-12-05 - [2884.TW] Order Canceled/Margin/Rejected
# 2024-12-05 - [4912.TW] Order Canceled/Margin/Rejected
# 2024-12-05 - [6805.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-05 - 選股結果: Picker選出 118 檔 -> 與BT匹配成功 118 檔 (範例: ['1217.TW', '912000.TW', '2069.TW', '2535.TW', '1315.TW'] ...)
# 2024-12-05 - [00670L.TW] ENTRY LONG, Price: 140.00, Size: 1934, N: 2.49, Stop: 135.03, Next Add: 141.24
# 2024-12-05 - [00861.TW] ENTRY LONG, Price: 43.63, Size: 10239, N: 0.47, Stop: 42.69, Next Add: 43.86
# 2024-12-05 - [2478.TW] ENTRY LONG, Price: 48.18, Size: 3642, N: 1.32, Stop: 45.54, Next Add: 48.84
# 2024-12-05 - [2535.TW] ENTRY LONG, Price: 48.30, Size: 6453, N: 0.75, Stop: 46.81, Next Add: 48.67
# 2024-12-05 - [3026.TW] ENTRY LONG, Price: 85.39, Size: 4253, N: 1.13, Stop: 83.13, Next Add: 85.96
# 2024-12-05 - [6024.TW] ENTRY LONG, Price: 56.06, Size: 5478, N: 0.88, Stop: 54.30, Next Add: 56.50
# 2024-12-05 - [6715.TW] ENTRY LONG, Price: 190.74, Size: 539, N: 8.92, Stop: 172.91, Next Add: 195.20
# 2024-12-05 - [8940.TW] ENTRY LONG, Price: 24.20, Size: 8183, N: 0.59, Stop: 23.02, Next Add: 24.49
# 2024-12-06 - [00670L.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [00861.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [2478.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [2535.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [3026.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [6024.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [6715.TW] Order Canceled/Margin/Rejected
# 2024-12-06 - [8940.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-06 - 選股結果: Picker選出 109 檔 -> 與BT匹配成功 109 檔 (範例: ['912000.TW', '2606.TW', '1315.TW', '3703.TW', '1467.TW'] ...)
# 2024-12-06 - [00653L.TW] ENTRY LONG, Price: 62.35, Size: 3280, N: 1.46, Stop: 59.42, Next Add: 63.08
# 2024-12-06 - [1231.TW] ENTRY LONG, Price: 114.99, Size: 1824, N: 2.63, Stop: 109.74, Next Add: 116.31
# 2024-12-06 - [1612.TW] ENTRY LONG, Price: 34.29, Size: 6255, N: 0.77, Stop: 32.76, Next Add: 34.67
# 2024-12-06 - [3591.TW] ENTRY LONG, Price: 26.72, Size: 4790, N: 1.00, Stop: 24.72, Next Add: 27.22
# 2024-12-06 - [4919.TW] ENTRY LONG, Price: 104.90, Size: 963, N: 4.98, Stop: 94.94, Next Add: 107.39
# 2024-12-06 - [8081.TW] ENTRY LONG, Price: 222.40, Size: 822, N: 5.83, Stop: 210.73, Next Add: 225.32
# 2024-12-09 - [00653L.TW] Order Canceled/Margin/Rejected
# 2024-12-09 - [1231.TW] Order Canceled/Margin/Rejected
# 2024-12-09 - [1612.TW] Order Canceled/Margin/Rejected
# 2024-12-09 - [3591.TW] Order Canceled/Margin/Rejected
# 2024-12-09 - [4919.TW] Order Canceled/Margin/Rejected
# 2024-12-09 - [8081.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-09 - 選股結果: Picker選出 158 檔 -> 與BT匹配成功 158 檔 (範例: ['6674.TW', '1725.TW', '912000.TW', '5521.TW', '2450.TW'] ...)
# 2024-12-09 - [00670L.TW] ENTRY LONG, Price: 141.75, Size: 1972, N: 2.41, Stop: 136.93, Next Add: 142.96
# 2024-12-09 - [00885.TW] ENTRY LONG, Price: 11.83, Size: 32847, N: 0.14, Stop: 11.54, Next Add: 11.90
# 2024-12-09 - [1464.TW] ENTRY LONG, Price: 16.76, Size: 6620, N: 0.72, Stop: 15.32, Next Add: 17.12
# 2024-12-09 - [2107.TW] ENTRY LONG, Price: 24.99, Size: 15648, N: 0.30, Stop: 24.38, Next Add: 25.14
# 2024-12-09 - [2436.TW] ENTRY LONG, Price: 61.80, Size: 1897, N: 2.51, Stop: 56.79, Next Add: 63.06
# 2024-12-09 - [2480.TW] ENTRY LONG, Price: 136.22, Size: 1472, N: 3.23, Stop: 129.76, Next Add: 137.83
# 2024-12-09 - [3051.TW] ENTRY LONG, Price: 31.65, Size: 4551, N: 1.04, Stop: 29.56, Next Add: 32.17
# 2024-12-09 - [5284.TW] ENTRY LONG, Price: 178.72, Size: 510, N: 9.31, Stop: 160.10, Next Add: 183.38
# 2024-12-09 - [6141.TW] ENTRY LONG, Price: 15.45, Size: 8292, N: 0.57, Stop: 14.30, Next Add: 15.74
# 2024-12-10 - [00670L.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [00885.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [1464.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [2107.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [2436.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [2480.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [3051.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [5284.TW] Order Canceled/Margin/Rejected
# 2024-12-10 - [6141.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-10 - 選股結果: Picker選出 178 檔 -> 與BT匹配成功 178 檔 (範例: ['6674.TW', '00918.TW', '912000.TW', '5521.TW', '3661.TW'] ...)
# 2024-12-10 - [00638R.TW] EXIT LONG (被踢出選股池), Price: 8.20, Stop: 8.250044126541912, S1Low: 8.41, S2Low: 8.14
# 2024-12-10 - [00651R.TW] EXIT LONG, Price: 7.33, Stop: 7.168373235265547, S1Low: 7.51, S2Low: 7.31
# 2024-12-10 - [2353.TW] ENTRY LONG, Price: 38.12, Size: 4849, N: 0.97, Stop: 36.18, Next Add: 38.60
# 2024-12-10 - [2374.TW] ENTRY LONG, Price: 43.79, Size: 3046, N: 1.54, Stop: 40.71, Next Add: 44.57
# 2024-12-10 - [6834.TW] ENTRY LONG, Price: 35.44, Size: 2878, N: 1.63, Stop: 32.18, Next Add: 36.26
# 2024-12-10 - [911608.TW] ENTRY LONG, Price: 3.53, Size: 35882, N: 0.13, Stop: 3.27, Next Add: 3.60
# 2024-12-11 - [6834.TW] Order Canceled/Margin/Rejected
# 2024-12-11 - [911608.TW] Order Canceled/Margin/Rejected
# 2024-12-11 - [00638R.TW] SELL EXECUTED, Price: 8.42, Size: -24279, Cost: 211712.89
# 2024-12-11 - [00651R.TW] SELL EXECUTED, Price: 7.36, Size: -21488, Cost: 165027.84
# 2024-12-11 - [2353.TW] BUY EXECUTED, Price: 36.78, Size: 4849, Cost: 178362.62
# 2024-12-11 - [2374.TW] BUY EXECUTED, Price: 43.17, Size: 3046, Cost: 131505.14
# 2024-12-11 - [00638R.TW] TRADE PROFIT, Gross: -7283.70, Net: -7699.85
# 2024-12-11 - [00651R.TW] TRADE PROFIT, Gross: -6876.15, Net: -7199.33
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-11 - 選股結果: Picker選出 186 檔 -> 與BT匹配成功 185 檔 (範例: ['00918.TW', '1410.TW', '912000.TW', '9908.TW', '00640L.TW'] ...)
# 2024-12-11 - [00738U.TW] ENTRY LONG, Price: 28.70, Size: 8964, N: 0.53, Stop: 27.65, Next Add: 28.96
# 2024-12-11 - [1416.TW] ENTRY LONG, Price: 13.05, Size: 13037, N: 0.36, Stop: 12.33, Next Add: 13.23
# 2024-12-11 - [6216.TW] ENTRY LONG, Price: 39.99, Size: 3434, N: 1.37, Stop: 37.25, Next Add: 40.68
# 2024-12-11 - [911608.TW] ENTRY LONG, Price: 3.90, Size: 31616, N: 0.15, Stop: 3.60, Next Add: 3.97
# 2024-12-12 - [00738U.TW] Order Canceled/Margin/Rejected
# 2024-12-12 - [1416.TW] Order Canceled/Margin/Rejected
# 2024-12-12 - [6216.TW] Order Canceled/Margin/Rejected
# 2024-12-12 - [911608.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-12 - 選股結果: Picker選出 188 檔 -> 與BT匹配成功 187 檔 (範例: ['00850.TW', '00638R.TW', '3023.TW', '00918.TW', '1410.TW'] ...)
# 2024-12-12 - [0051.TW] ENTRY LONG, Price: 77.37, Size: 4033, N: 1.17, Stop: 75.04, Next Add: 77.95
# 2024-12-12 - [00640L.TW] ENTRY LONG, Price: 55.05, Size: 3899, N: 1.20, Stop: 52.64, Next Add: 55.65
# 2024-12-12 - [00645.TW] ENTRY LONG, Price: 38.25, Size: 10857, N: 0.43, Stop: 37.38, Next Add: 38.47
# 2024-12-12 - [00657K.TW] ENTRY LONG, Price: 14.46, Size: 38413, N: 0.12, Stop: 14.22, Next Add: 14.52
# 2024-12-12 - [00738U.TW] ENTRY LONG, Price: 28.93, Size: 9182, N: 0.51, Stop: 27.91, Next Add: 29.19
# 2024-12-12 - [2313.TW] ENTRY LONG, Price: 64.82, Size: 2060, N: 2.28, Stop: 60.26, Next Add: 65.96
# 2024-12-12 - [4540.TW] ENTRY LONG, Price: 50.00, Size: 1682, N: 2.79, Stop: 44.41, Next Add: 51.40
# 2024-12-12 - [4571.TW] ENTRY LONG, Price: 187.55, Size: 445, N: 10.54, Stop: 166.47, Next Add: 192.82
# 2024-12-13 - [0051.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [00640L.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [00645.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [00657K.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [00738U.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [2313.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [4540.TW] Order Canceled/Margin/Rejected
# 2024-12-13 - [4571.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-13 - 選股結果: Picker選出 173 檔 -> 與BT匹配成功 172 檔 (範例: ['00850.TW', '3023.TW', '00918.TW', '3419.TW', '4942.TW'] ...)
# 2024-12-13 - [2353.TW] EXIT LONG (被踢出選股池), Price: 35.69, Stop: 36.176458984762846, S1Low: 35.50, S2Low: 35.26
# 2024-12-13 - [2374.TW] PYRAMID ADD, Price: 45.70, Size: 2720, Units: 2, Next Add: 45.43
# 2024-12-13 - [4540.TW] ENTRY LONG, Price: 51.60, Size: 1587, N: 2.95, Stop: 45.70, Next Add: 53.07
# 2024-12-13 - [6215.TW] ENTRY LONG, Price: 70.85, Size: 1446, N: 3.24, Stop: 64.38, Next Add: 72.47
# 2024-12-16 - [6215.TW] Order Canceled/Margin/Rejected
# 2024-12-16 - [2353.TW] SELL EXECUTED, Price: 34.93, Size: -4849, Cost: 178362.62
# 2024-12-16 - [2374.TW] BUY EXECUTED, Price: 48.81, Size: 2720, Cost: 132758.26
# 2024-12-16 - [4540.TW] BUY EXECUTED, Price: 50.90, Size: 1587, Cost: 80778.30
# 2024-12-16 - [2353.TW] TRADE PROFIT, Gross: -8998.89, Net: -9346.61
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-16 - 選股結果: Picker選出 144 檔 -> 與BT匹配成功 142 檔 (範例: ['3023.TW', '00918.TW', '9906.TW', '4942.TW', '6838.TW'] ...)
# 2024-12-16 - [3443.TW] ENTRY LONG, Price: 1335.20, Size: 69, N: 66.01, Stop: 1203.19, Next Add: 1368.20
# 2024-12-17 - [3443.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-17 - 選股結果: Picker選出 135 檔 -> 與BT匹配成功 133 檔 (範例: ['9934.TW', '4942.TW', '1315.TW', '00852L.TW', '4536.TW'] ...)
# 2024-12-17 - [1213.TW] ENTRY LONG, Price: 15.28, Size: 10865, N: 0.43, Stop: 14.41, Next Add: 15.49
# 2024-12-18 - [1213.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-18 - 選股結果: Picker選出 126 檔 -> 與BT匹配成功 125 檔 (範例: ['00706L.TW', '3416.TW', '6579.TW', '4942.TW', '1315.TW'] ...)
# 2024-12-18 - [1213.TW] ENTRY LONG, Price: 16.79, Size: 9847, N: 0.49, Stop: 15.81, Next Add: 17.03
# 2024-12-18 - [1597.TW] ENTRY LONG, Price: 98.88, Size: 1004, N: 4.77, Stop: 89.33, Next Add: 101.27
# 2024-12-18 - [2739.TW] ENTRY LONG, Price: 52.07, Size: 3155, N: 1.52, Stop: 49.03, Next Add: 52.82
# 2024-12-18 - [5484.TW] ENTRY LONG, Price: 66.50, Size: 1227, N: 3.91, Stop: 58.69, Next Add: 68.45
# 2024-12-19 - [1213.TW] Order Canceled/Margin/Rejected
# 2024-12-19 - [1597.TW] Order Canceled/Margin/Rejected
# 2024-12-19 - [2739.TW] Order Canceled/Margin/Rejected
# 2024-12-19 - [5484.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-19 - 選股結果: Picker選出 127 檔 -> 與BT匹配成功 127 檔 (範例: ['00706L.TW', '3416.TW', '6579.TW', '4942.TW', '2012.TW'] ...)
# 2024-12-19 - [00682U.TW] ENTRY LONG, Price: 21.84, Size: 55932, N: 0.08, Stop: 21.67, Next Add: 21.88
# 2024-12-19 - [00683L.TW] ENTRY LONG, Price: 24.57, Size: 21900, N: 0.22, Stop: 24.14, Next Add: 24.68
# 2024-12-19 - [5515.TW] EXIT LONG, Price: 24.51, Stop: nan, S1Low: 24.60, S2Low: 24.51
# 2024-12-19 - [5546.TW] ENTRY LONG, Price: 28.50, Size: 9981, N: 0.47, Stop: 27.55, Next Add: 28.73
# 2024-12-20 - [00682U.TW] Order Canceled/Margin/Rejected
# 2024-12-20 - [00683L.TW] Order Canceled/Margin/Rejected
# 2024-12-20 - [5515.TW] Order Canceled/Margin/Rejected
# 2024-12-20 - [5546.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-20 - 選股結果: Picker選出 108 檔 -> 與BT匹配成功 108 檔 (範例: ['00647L.TW', '6579.TW', '4942.TW', '6914.TW', '6205.TW'] ...)
# 2024-12-20 - [00682U.TW] ENTRY LONG, Price: 22.07, Size: 53392, N: 0.09, Stop: 21.89, Next Add: 22.12
# 2024-12-20 - [00689R.TW] ENTRY LONG, Price: 22.15, Size: 29575, N: 0.17, Stop: 21.82, Next Add: 22.23
# 2024-12-20 - [2250.TW] ENTRY LONG, Price: 105.18, Size: 1288, N: 3.81, Stop: 97.57, Next Add: 107.09
# 2024-12-23 - [00682U.TW] Order Canceled/Margin/Rejected
# 2024-12-23 - [00689R.TW] Order Canceled/Margin/Rejected
# 2024-12-23 - [2250.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-23 - 選股結果: Picker選出 104 檔 -> 與BT匹配成功 103 檔 (範例: ['6914.TW', '910322.TW', '00640L.TW', '3593.TW', '00642U.TW'] ...)
# 2024-12-23 - [00654R.TW] ENTRY LONG, Price: 6.68, Size: 63319, N: 0.08, Stop: 6.52, Next Add: 6.72
# 2024-12-23 - [2250.TW] ENTRY LONG, Price: 115.33, Size: 1204, N: 4.12, Stop: 107.09, Next Add: 117.39
# 2024-12-23 - [2314.TW] ENTRY LONG, Price: 84.31, Size: 1292, N: 3.84, Stop: 76.62, Next Add: 86.23
# 2024-12-23 - [3543.TW] ENTRY LONG, Price: 23.07, Size: 9767, N: 0.51, Stop: 22.06, Next Add: 23.33
# 2024-12-24 - [00654R.TW] Order Canceled/Margin/Rejected
# 2024-12-24 - [2250.TW] Order Canceled/Margin/Rejected
# 2024-12-24 - [2314.TW] Order Canceled/Margin/Rejected
# 2024-12-24 - [3543.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-24 - 選股結果: Picker選出 107 檔 -> 與BT匹配成功 105 檔 (範例: ['6914.TW', '910322.TW', '00640L.TW', '3593.TW', '01010T.TW'] ...)
# 2024-12-24 - [00929.TW] ENTRY LONG, Price: 17.42, Size: 24008, N: 0.21, Stop: 17.01, Next Add: 17.52
# 2024-12-24 - [3034.TW] ENTRY LONG, Price: 476.63, Size: 484, N: 10.18, Stop: 456.26, Next Add: 481.72
# 2024-12-24 - [4722.TW] ENTRY LONG, Price: 45.56, Size: 4862, N: 1.01, Stop: 43.53, Next Add: 46.07
# 2024-12-24 - [9917.TW] EXIT LONG (被踢出選股池), Price: 121.43, Stop: nan, S1Low: 121.43, S2Low: 121.43
# 2024-12-25 - [00929.TW] Order Canceled/Margin/Rejected
# 2024-12-25 - [3034.TW] Order Canceled/Margin/Rejected
# 2024-12-25 - [4722.TW] Order Canceled/Margin/Rejected
# 2024-12-25 - [9917.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-25 - 選股結果: Picker選出 102 檔 -> 與BT匹配成功 100 檔 (範例: ['6914.TW', '6205.TW', '910322.TW', '00640L.TW', '3593.TW'] ...)
# 2024-12-25 - [1558.TW] ENTRY LONG, Price: 104.13, Size: 2305, N: 2.14, Stop: 99.84, Next Add: 105.20
# 2024-12-25 - [1733.TW] ENTRY LONG, Price: 29.41, Size: 7288, N: 0.68, Stop: 28.06, Next Add: 29.75
# 2024-12-25 - [3059.TW] ENTRY LONG, Price: 39.51, Size: 3106, N: 1.59, Stop: 36.33, Next Add: 40.30
# 2024-12-25 - [6928.TW] ENTRY LONG, Price: 64.32, Size: 2119, N: 2.33, Stop: 59.67, Next Add: 65.49
# 2024-12-26 - [1558.TW] Order Canceled/Margin/Rejected
# 2024-12-26 - [1733.TW] Order Canceled/Margin/Rejected
# 2024-12-26 - [3059.TW] Order Canceled/Margin/Rejected
# 2024-12-26 - [6928.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-26 - 選股結果: Picker選出 108 檔 -> 與BT匹配成功 106 檔 (範例: ['3023.TW', '6579.TW', '6914.TW', '6205.TW', '910322.TW'] ...)
# 2024-12-26 - [2231.TW] ENTRY LONG, Price: 108.23, Size: 1174, N: 4.35, Stop: 99.53, Next Add: 110.40
# 2024-12-26 - [6166.TW] ENTRY LONG, Price: 79.79, Size: 1724, N: 2.96, Stop: 73.86, Next Add: 81.27
# 2024-12-27 - [2231.TW] Order Canceled/Margin/Rejected
# 2024-12-27 - [6166.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-27 - 選股結果: Picker選出 103 檔 -> 與BT匹配成功 99 檔 (範例: ['3023.TW', '6579.TW', '6914.TW', '910322.TW', '00640L.TW'] ...)
# 2024-12-27 - [00640L.TW] ENTRY LONG, Price: 55.25, Size: 4263, N: 1.16, Stop: 52.93, Next Add: 55.83
# 2024-12-27 - [00645.TW] ENTRY LONG, Price: 38.47, Size: 12187, N: 0.41, Stop: 37.66, Next Add: 38.67
# 2024-12-27 - [1786.TW] ENTRY LONG, Price: 94.18, Size: 1425, N: 3.47, Stop: 87.24, Next Add: 95.91
# 2024-12-27 - [2434.TW] ENTRY LONG, Price: 33.05, Size: 7960, N: 0.62, Stop: 31.81, Next Add: 33.36
# 2024-12-30 - [00640L.TW] Order Canceled/Margin/Rejected
# 2024-12-30 - [00645.TW] Order Canceled/Margin/Rejected
# 2024-12-30 - [1786.TW] Order Canceled/Margin/Rejected
# 2024-12-30 - [2434.TW] Order Canceled/Margin/Rejected
#
# --- 正在執行選股過程並記錄詳細因子結果 ---
#
# --- 詳細因子結果已儲存至 self.factor_results_df ---
# 2024-12-30 - 選股結果: Picker選出 110 檔 -> 與BT匹配成功 110 檔 (範例: ['3023.TW', '3416.TW', '6579.TW', '6239.TW', '4942.TW'] ...)
# 2024-12-30 - [3592.TW] ENTRY LONG, Price: 371.11, Size: 485, N: 10.26, Stop: 350.58, Next Add: 376.24
# 2024-12-30 - [3645.TW] ENTRY LONG, Price: 48.48, Size: 2553, N: 1.95, Stop: 44.57, Next Add: 49.45
#
# Final Portfolio Value: 996810.05
# Total Return: -0.32%
