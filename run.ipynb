# %%
from alanq.data import StockDataManager

data = StockDataManager(country_code="TW", start_date="2025-11-20")
data.get_stock_data_by_symbol('0050.TW')
# Out:
# 正在從台灣證交所 API 抓取股票代號...
# 成功抓取 1321 檔台灣股票代號
# 正在使用 yfinance 下載 1321 檔股票資料...
# 正在下載第 1 批（共 100 檔）...
# 正在下載第 2 批（共 100 檔）...
# 正在下載第 3 批（共 100 檔）...
# 4 Failed downloads:
# ['020012.TW', '020011.TW', '020036.TW', '020000.TW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-20 -> 2025-11-23)')
# 正在下載第 4 批（共 100 檔）...
# 正在下載第 5 批（共 100 檔）...
# 正在下載第 6 批（共 100 檔）...
# 正在下載第 7 批（共 100 檔）...
# 正在下載第 8 批（共 100 檔）...
# 正在下載第 9 批（共 100 檔）...
# 正在下載第 10 批（共 100 檔）...
# 正在下載第 11 批（共 100 檔）...
# 正在下載第 12 批（共 100 檔）...
# 正在下載第 13 批（共 100 檔）...
# 正在下載第 14 批（共 21 檔）...
# ------------------------------
# 已成功下載 1321 檔股票資料
#   - 0050.TW: 2 筆資料，日期範圍 2025-11-20 至 2025-11-21
#   - 0051.TW: 2 筆資料，日期範圍 2025-11-20 至 2025-11-21
#   - 0053.TW: 2 筆資料，日期範圍 2025-11-20 至 2025-11-21
#   - 0055.TW: 2 筆資料，日期範圍 2025-11-20 至 2025-11-21
#   - 0056.TW: 2 筆資料，日期範圍 2025-11-20 至 2025-11-21
#   ... 還有 1316 檔股票
# ------------------------------
# ...
